# %%
# %run .\robust_ceir_wasserstein_v1.py --alpha 0.95 --delta 0.01
# %run .\robust_ceir_wasserstein_v2.py --alpha 0.95 --delta 0.01
# %run .\robust_cleir_wasserstein_v1.py --alpha 0.95 --delta 0.01
# %run .\robust_cleir_wasserstein_v2.py --alpha 0.95 --delta 0.01
# Out:
# Loaded data
# Stock returns      : (5030, 503)
# Benchmark returns  : (5030,)
# Dates matched      : True
# 2008-01-02 | train=2007 year (251 days) | hold=2008 (253 days) | available=100 | selected=100 | time=4.782s
# 2009-01-02 | train=2008 year (253 days) | hold=2009 (252 days) | available=100 | selected=77  | time=4.885s
# 2010-01-04 | train=2009 year (252 days) | hold=2010 (252 days) | available=100 | selected=84  | time=4.841s
# 2011-01-03 | train=2010 year (252 days) | hold=2011 (252 days) | available=100 | selected=94  | time=4.811s
# 2012-01-03 | train=2011 year (252 days) | hold=2012 (250 days) | available=100 | selected=97  | time=5.137s
# 2013-01-02 | train=2012 year (250 days) | hold=2013 (252 days) | available=100 | selected=91  | time=4.596s
# 2014-01-02 | train=2013 year (252 days) | hold=2014 (252 days) | available=100 | selected=100 | time=4.885s
# 2015-01-02 | train=2014 year (252 days) | hold=2015 (252 days) | available=100 | selected=93  | time=5.104s
# ...

# %%
# %run .\plot_exp3.py
