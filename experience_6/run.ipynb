# %%
# ============================================================
# download
# ============================================================

# %run .\download_sp500.py

# %%
# ============================================================
# calculate
# ============================================================

# %run .\robust_po.py --alpha 0.95 --delta 0.01
# %run .\robust_po_lasso.py --alpha 0.95 --delta 0.01
# %run .\robust_po_with_return_constraint.py --alpha 0.95 --delta 0.01
# %run .\robust_po_lasso_with_return_constraint.py --alpha 0.95 --delta 0.01
# Out:
# ...
#               Selected stock data check
# ...
# Required period   : 2014-01-01 ~ 2020-12-31
# Selected stocks   : 30
# Min availability  : 95%
#
# Ticker  First       Last           Missing   Availability
# ---------------------------------------------------------
# AAPL    2014-01-02  2020-12-31           0       100.00%
# MSFT    2014-01-02  2020-12-31           0       100.00%
# NVDA    2014-01-02  2020-12-31           0       100.00%
# AMZN    2014-01-02  2020-12-31           0       100.00%
# GOOG    2014-01-02  2020-12-31           0       100.00%
# META    2014-01-02  2020-12-31           0       100.00%
# BRK-B   2014-01-02  2020-12-31           0       100.00%
# JPM     2014-01-02  2020-12-31           0       100.00%
# JNJ     2014-01-02  2020-12-31           0       100.00%
# V       2014-01-02  2020-12-31           0       100.00%
# PG      2014-01-02  2020-12-31           0       100.00%
# XOM     2014-01-02  2020-12-31           0       100.00%
# ...

# %%
# ============================================================
# plot
# ============================================================

# %run .\plot.py
